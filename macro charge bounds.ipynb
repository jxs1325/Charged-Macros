# %%
#mica lower bound

import numpy as np
import math
from scipy.special import erf
from scipy.optimize import fsolve

M2 = 10.0*1.67*10**-27*1000.0
Z2 = 10.0
#Z1 = 10**10 #temp
N = 10.0**23

v=[]
Mhold=[]
Zhold=[]
E=[]

def fun(Z1):
    return 0.5*(math.log(1+1.1383*4.68*10**-9*M2*(vrel)**2/(2*Z1**1.23*Z2*(4.8*10**-10)**2))/(4.68*10**-9*M2*(vrel)**2/(2*Z1**1.23*Z2*(4.8*10**-10)**2) + 0.01321*(4.68*10**-9*M2*(vrel)**2/(2*Z1**1.23*Z2*(4.8*10**-10)**2))**0.21226+0.19593*(4.68*10**-9*M2*(vrel)**2/(2*Z1**1.23*Z2*(4.8*10**-10)**2))**0.5 )) * (N*8.462*10**-15*Z1**0.77*Z2) - 5*10.0**9
    #return (0.5*(math.log(4.68*10**-9*M2*(vrel)**2/(2*(Z1**0.23+Z2**0.23)*Z1*Z2*(4.8*10**-10)**2))/(4.68*10**-9*M2*(vrel)**2/(2*(Z1**0.23+Z2**0.23)*Z1*Z2*(4.8*10**-10)**2)))*(N*8.462*10**-15*Z1**0.77*Z2) - 5*10.0**9)

for i in range(0,22):
    vx=-550.0+i*50.0
    for j in range(0,22):
        vz=-550.0+j*50.0
        for k in range(0,22):
            vy=-550.0+k*50.0  #this is in the Galactic rest frame
            #print(np.sqrt(vx**2+vy**2+vz**2))
            if (np.sqrt(vx**2+vy**2+vz**2)>550.0):
                a=1
                #do nothing
            else:
                vrel=np.sqrt(42.1**2+vx**2+vz**2+(vy-200.0)**2)*10**5*1.0   #10**5 converts km to cm; we want cgs
                fracx=erf(11.0/5)-erf(abs(vx)/250.0)
                fracz=erf(11.0/5)-erf(abs(vz)/250.0)
                fracy1=0.5*(erf(11.0/5)-erf(vy/250.0))
                vy2=abs(vy-200.0)-200.0
                fracy2=0.5*(erf(11.0/5)-erf(vy2/250.0))
                if fracy1<0.0:
                    fracy1=0.0
                if fracy2<0.0:
                    fracy2=0.0
                fracy=fracy1+fracy2
                frac=fracx*fracy*fracz
    #                 if frac>1.0:
    #                     print('frac greater than 1.0',fracx,fracy,fracz)
    #             vrel=250
    #                 epsilon = 4.68*10**-8*M2*vrel**2/(2*Z1**1.23*Z2*(4.8*10**-10)**2)
                Mx = 55 * frac
    #             if Mx == 0:
    #                 break
                Mhold.append(Mx)
                
# print(min(Zhold))

#                 Sepsilon = math.log(1+1.1383*epsilon)/(epsilon + 0.01321*epsilon**0.21226+0.19593*epsilon**0.5)

                x0 = fsolve(fun,1)
    #                 print(x0)
                
        #                 Z1=10**15
#                 epsilon = 4.68*10**-9*M2*(vrel)**2/(2*(x0[0])**1.23*Z2*(4.8*10**-10)**2)
#                 E.append(vrel)
                f=3*10**5*0.5*(math.log(1+1.1383*4.68*10**-9*M2*(vrel)**2/(2*x0[0]**1.23*Z2*(4.8*10**-10)**2))/(4.68*10**-9*M2*(vrel)**2/(2*x0[0]**1.23*Z2*(4.8*10**-10)**2) + 0.01321*(4.68*10**-9*M2*(vrel)**2/(2*x0[0]**1.23*Z2*(4.8*10**-10)**2))**0.21226+0.19593*(4.68*10**-9*M2*(vrel)**2/(2*x0[0]**1.23*Z2*(4.8*10**-10)**2))**0.5 )) * (N*8.462*10**-15*x0[0]**0.77*Z2)
                Zhold.append(f)
#                 Mx=min(55,2*f*1.6*10**-10/(vrel**2))
#                 Mhold.append(Mx)
#                 if f>10**-3:
#                     print('greater than 0.001')
#                 elif f<-10**-3:
#                     print('greater than 0.001, negative')
#                 else:
#                     a=1
                    #do nothin
    #                 print(epsilon)
#                 v.append(vrel)
#                 print(vrel,x0[0])
#                 dEdx = Sepsilon * N *8.462*10**-15*Z1**0.77*Z2
#                 print(dEdx/(10**20),epsilon,dEdx*300000*1.6*10**-19)
# print(max(E),min(E))
# print(Zhold)
S=[]
M=[]
V=[]
Stemp=[]
Vtemp=[]
for k in range(1,9):
    for i in range(1,10):
        Stemp=[]
        for h in range(len(Mhold)):
            if (5.5*10**-5)*i*10**k < Mhold[h] < (5.5*10**-5)*(i+1)*10**k:
#                 print(Mhold[h],Shold[h])
#                 print((i+1)*10**k)
#                 print(Shold[h])
                Stemp.append(Zhold[h])
#                 Vtemp.append(Zhold[h])
        if len(Stemp) > 0:
            S.append(min(Stemp))
#             V.append(min(Vtemp))
            M.append(5.5*10**-5*(2*i+1)*10**k/2)
        
print(M,S)

# %%
#macro experiment lower bound

import numpy as np
import math
from scipy.special import erf
from scipy.optimize import fsolve

M2 = 10.0*1.67*10**-27*1000.0
Z2 = 10.0
#Z1 = 10**10 #temp
N = 10.0**23

v=[]
Mhold=[]
Zhold=[]
E=[]

def fun(Z1):
    #return 0.5*(math.log(1+1.1383*4.68*10**-9*M2*(vrel)**2/(2*Z1**1.23*Z2*(4.8*10**-10)**2))/(4.68*10**-9*M2*(vrel)**2/(2*Z1**1.23*Z2*(4.8*10**-10)**2) + 0.01321*(4.68*10**-9*M2*(vrel)**2/(2*Z1**1.23*Z2*(4.8*10**-10)**2))**0.21226+0.19593*(4.68*10**-9*M2*(vrel)**2/(2*Z1**1.23*Z2*(4.8*10**-10)**2))**0.5 )) * (N*8.462*10**-15*Z1**0.77*Z2) - 5*10.0**6
    return (0.5*(math.log(4.68*10**-9*M2*(vrel)**2/(2*(Z1**0.23+Z2**0.23)*Z1*Z2*(4.8*10**-10)**2))/(4.68*10**-9*M2*(vrel)**2/(2*(Z1**0.23+Z2**0.23)*Z1*Z2*(4.8*10**-10)**2)))*(N*8.462*10**-15*Z1**0.77*Z2) - 5*10.0**6)

for i in range(0,16):
    vx=-550.0+i*50.0
    for j in range(0,16):
        vz=-550.0+j*50.0
        for k in range(0,16):
            vy=-550.0+k*50.0  #this is in the Galactic rest frame
            #print(np.sqrt(vx**2+vy**2+vz**2))
            if (np.sqrt(vx**2+vy**2+vz**2)>550.0):
                a=1
                #do nothing
            else:
                vrel=np.sqrt(42.1**2+vx**2+vz**2+(vy-200.0)**2)*10**5*1.0   #10**5 converts km to cm; we want cgs
                fracx=erf(11.0/5)-erf(abs(vx)/250.0)
                fracz=erf(11.0/5)-erf(abs(vz)/250.0)
                fracy1=0.5*(erf(11.0/5)-erf(vy/250.0))
                vy2=abs(vy-200.0)-200.0
                fracy2=0.5*(erf(11.0/5)-erf(vy2/250.0))
                if fracy1<0.0:
                    fracy1=0.0
                if fracy2<0.0:
                    fracy2=0.0
                fracy=fracy1+fracy2
                frac=fracx*fracy*fracz
    #                 if frac>1.0:
    #                     print('frac greater than 1.0',fracx,fracy,fracz)
    #             vrel=250
    #                 epsilon = 4.68*10**-8*M2*vrel**2/(2*Z1**1.23*Z2*(4.8*10**-10)**2)
                Mx = 0.0055 * frac
    #             if Mx == 0:
    #                 break
                Mhold.append(Mx)

#                 Sepsilon = math.log(1+1.1383*epsilon)/(epsilon + 0.01321*epsilon**0.21226+0.19593*epsilon**0.5)

                x0 = fsolve(fun,0.08)
    #                 print(x0)
                Zhold.append(x0[0])
        #                 Z1=10**15
                epsilon = 4.68*10**-9*M2*(vrel)**2/(2*(x0[0])**1.23*Z2*(4.8*10**-10)**2)
                E.append(vrel)
                f=0.5*(math.log(1+1.1383*4.68*10**-9*M2*(vrel)**2/(2*x0[0]**1.23*Z2*(4.8*10**-10)**2))/(4.68*10**-9*M2*(vrel)**2/(2*x0[0]**1.23*Z2*(4.8*10**-10)**2) + 0.01321*(4.68*10**-9*M2*(vrel)**2/(2*x0[0]**1.23*Z2*(4.8*10**-10)**2))**0.21226+0.19593*(4.68*10**-9*M2*(vrel)**2/(2*x0[0]**1.23*Z2*(4.8*10**-10)**2))**0.5 )) * (N*8.462*10**-15*x0[0]**0.77*Z2) - 5*10.0**6
#                 if f>10**-8:
#                     print('greater than 0.001')
#                 elif f<-10**-8:
#                     print('greater than 0.001, negative')
#                 else:
#                     a=1
#                     #do nothin
    #                 print(epsilon)
#                 v.append(vrel)
#                 print(vrel,x0[0])
#                 dEdx = Sepsilon * N *8.462*10**-15*Z1**0.77*Z2
#                 print(dEdx/(10**20),epsilon,dEdx*300000*1.6*10**-19)
# print(max(E),min(E))
# print(Zhold)
S=[]
M=[]
V=[]
Stemp=[]
Vtemp=[]
for k in range(1,9):
    for i in range(1,10):
        Stemp=[]
        for h in range(len(Mhold)):
            if (5.5*10**-7)*i*10**k < Mhold[h] < (5.5*10**-7)*(i+1)*10**k:
#                 print(Mhold[h],Shold[h])
#                 print((i+1)*10**k)
#                 print(Shold[h])
                Stemp.append(Zhold[h])
                Vtemp.append(E[h])
        if len(Stemp) > 0:
            S.append(min(Stemp))
            V.append(min(Vtemp))
            M.append(5.5*10**-7*(2*i+1)*10**k/2)
        
print(M,S,V)

# %%
#upper bound for macro 
M2 = 10.0*1.67*10**-27*1000.0
Z2 = 10.0
#Z1 = 10**10 #temp
N = 10.0**23

Mhold=[]
Zhold=[]

for i in range(0,16):
    vx=-550.0+i*50.0
    for j in range(0,16):
        vz=-550.0+j*50.0
        for k in range(0,16):
            vy=-550.0+k*50.0  #this is in the Galactic rest frame
            #print(np.sqrt(vx**2+vy**2+vz**2))
            if (np.sqrt(vx**2+vy**2+vz**2)>550.0):
                a=1
                #do nothing
            else:
                vrel=np.sqrt(42.1**2+vx**2+vz**2+(vy-200.0)**2)*10**5*1.0   #10**5 converts km to cm; we want cgs
                fracx=erf(11.0/5)-erf(abs(vx)/250.0)
                fracz=erf(11.0/5)-erf(abs(vz)/250.0)
                fracy1=0.5*(erf(11.0/5)-erf(vy/250.0))
                vy2=abs(vy-200.0)-200.0
                fracy2=0.5*(erf(11.0/5)-erf(vy2/250.0))
                if fracy1<0.0:
                    fracy1=0.0
                if fracy2<0.0:
                    fracy2=0.0
                fracy=fracy1+fracy2
                frac=fracx*fracy*fracz
    #                 if frac>1.0:
    #                     print('frac greater than 1.0',fracx,fracy,fracz)
    #             vrel=250
    #                 epsilon = 4.68*10**-8*M2*vrel**2/(2*Z1**1.23*Z2*(4.8*10**-10)**2)
                E.append(vrel)
                Mx = 0.0055 * frac
                Mhold.append(Mx)
                Z1 = 1.6*10**-9*vrel**2
               

                Zhold.append(Z1)
                
# print(len(Mhold),len(Zhold))
S=[]
M=[]
V=[]
Stemp=[]
Vtemp=[]
for k in range(1,9):
    for i in range(1,10):
        Stemp=[]
        for h in range(len(Mhold)):
            if (5.5*10**-7)*i*10**k < Mhold[h] < (5.5*10**-7)*(i+1)*10**k:
#                 print(Mhold[h],Shold[h])
#                 print((i+1)*10**k)
#                 print(Shold[h])
                Stemp.append(Zhold[h])
                Vtemp.append(E[h])
        if len(Stemp) > 0:
            S.append(min(Stemp))
            V.append(min(Vtemp))
            M.append(5.5*10**-7*(2*i+1)*10**k/2)
        
print(M,S,V)

# %%
M2 = 10.0*1.67*10**-27*1000.0
Z2 = 10.0
#Z1 = 10**10 #temp
N = 10.0**23

Mhold=[]
Zhold=[]

for i in range(0,16):
    vx=-550.0+i*50.0
    for j in range(0,16):
        vz=-550.0+j*50.0
        for k in range(0,16):
            vy=-550.0+k*50.0  #this is in the Galactic rest frame
            #print(np.sqrt(vx**2+vy**2+vz**2))
            if (np.sqrt(vx**2+vy**2+vz**2)>550.0):
                a=1
                #do nothing
            else:
                vrel=np.sqrt(42.1**2+vx**2+vz**2+(vy-200.0)**2)*10**5*1.0   #10**5 converts km to cm; we want cgs
                fracx=erf(11.0/5)-erf(abs(vx)/250.0)
                fracz=erf(11.0/5)-erf(abs(vz)/250.0)
                fracy1=0.5*(erf(11.0/5)-erf(vy/250.0))
                vy2=abs(vy-200.0)-200.0
                fracy2=0.5*(erf(11.0/5)-erf(vy2/250.0))
                if fracy1<0.0:
                    fracy1=0.0
                if fracy2<0.0:
                    fracy2=0.0
                fracy=fracy1+fracy2
                frac=fracx*fracy*fracz
    #                 if frac>1.0:
    #                     print('frac greater than 1.0',fracx,fracy,fracz)
    #             vrel=250
    #                 epsilon = 4.68*10**-8*M2*vrel**2/(2*Z1**1.23*Z2*(4.8*10**-10)**2)
                Mx = 55 * frac
                Mhold.append(Mx)
                Z1 = 1.6*10**-9*vrel**2
               

                Zhold.append(Z1)
                
# print(len(Mhold),len(Zhold))
S=[]
M=[]

Stemp=[]

for k in range(1,9):
    for i in range(1,10):
        Stemp=[]
        for h in range(len(Mhold)):
            if (5.5*10**-7)*i*10**k < Mhold[h] < (5.5*10**-7)*(i+1)*10**k:
#                 print(Mhold[h],Shold[h])
#                 print((i+1)*10**k)
#                 print(Shold[h])
                Stemp.append(Zhold[h])

        if len(Stemp) > 0:
            S.append(min(Stemp))
            M.append(5.5*10**-7*(2*i+1)*10**k/2)
        
print(M,S,len(M))

# %%
#neutron star charge bounds
#upper bound & maybe lower bounds as well

import numpy as np
import math
pi = np.pi
columnplaceholder=[0.001,0.01, 0.0061093530000000005, 0.9581980959999999, 4.613236296, 330.57172629600007, 
                   4314.640726296, 45664.040726296, 474806.09072629595, 4653761.0907262955, 41925856.09072629, 
                   350552356.0907262, 2676845556.090727, 17478245556.09073, 112766645556.09073, 674113445556.0907, 
                   3667003445556.091,21375961445556.09]
density=[7.865, 11.93, 45.17, 34.22, 647.9, 2454.0, 9292.0, 35190.0, 133300.0, 504699.99999999994, 1911000.0,
         7238000.0, 27410000.0, 103800000.0, 393100000.0, 1489000000.0,5.638*10**9,2.135*10**10]
L = [0.001,5.121*10**-4,2.159*10**-2,1.284*10**-1,6.315*10**-1,2.255*10**0,6.705*10**0,
    1.890*10**1,5.025*10**1,1.241*10**2,2.856*10**2,6.070*10**2,1.147*10**3,2.065*10**3,
    3.493*10**3,5.503*10**3,8.644*10**3,1.312*10**4,1.93*10**4]
pukimah=[]
bodoh=[]
l=[]
for i in range(len(columnplaceholder)):
    pukimah.append(math.log10(columnplaceholder[i]))
    bodoh.append(math.log10(density[i]))
    l.append(math.log10(L[i]))
# print(bodoh)
from scipy.interpolate import interp1d
import matplotlib.pyplot as plt


y0 = pukimah
x0 = bodoh

# print(y0,x0)

plt.plot(x0, l, 'o')

# # Array with points in between those of the data set for interpolation.
x = np.linspace(0.9,10.32)

# # Available options for interp1d
s = (2)

den=[]
f = interp1d(x0, y0, kind=s)    # interpolation function
g = interp1d(x0, l, kind=s)
plt.plot(x, g(x), label='Quadratic fit')# plot of interpolated data
p=10
trig=[]
colden=[]
Mupper=[]
for y in range(0,4):
    for i in range(1,p):
        rho = min(i*10**(7+y),2*10**10)
        if rho==2*10**10:
            break
#         print(rho)
#         rho=1.5*10**9
        if rho>5*10**8:
            trig.append(25*10**14/(rho**2))
            colden.append(10**f(math.log10(rho)))
            den.append(rho)
#             Mupper.append()
        elif 2*10**8<rho<4.999*10**8:
            trig.append(25*5*10**13/(rho**2))
            colden.append(10**f(math.log10(rho)))
            den.append(rho)
        elif rho<1.999*10**8:
            trig.append(25*2*10**13/(rho**2))
            colden.append(10**f(math.log10(rho)))
            den.append(rho)
# print(den)
# Mleft=[]
sigma=[]
Mright=[]
# print(len(trig))
for i in range(len(trig)):
#     if trig[i]<0.0138:
#         break
#     print(colden[i],trig[i])
#     Mleft.append(pi*(trig[i])**2*colden[i])
    sigma.append(pi*(trig[i])**2)
    Mright.append(5*10**10*(1-colden[i]/(8*10**12)))
    print(Mright[i],den[i])
# print(min(Mright)/(5*10**10))

Z=[]
for i in range(len(den)):
    Z.append((6*10**31/(den[i]))**0.5)
#     Zupper.append()



Rightbound = [[0.0]*2 for i in range(len(Mright))]
Leftbound = [[0.0]*2 for i in range(len(Mright))]

for i in range(len(Mright)):
    Rightbound[i][0]=Mright[i]
    Rightbound[i][1]=Z[i]
    Leftbound[i][0]=Mright[len(Mright) - i - 1]
    Leftbound[i][1]=(Mright[len(Mright) - i - 1]**0.5*(1.2*10**30/den[len(Mright) - i - 1])**0.5)
#     print(len(den),len(Mright))
# print(Rightbound)
print(Leftbound)

# %%
Macrolower=[0.04275455794733869, 0.04210369883848801, 0.04031872769101489, 0.03939708544950129, 0.03821496688786844, 0.036246507466864857, 0.036498159779284514, 0.03845419097636563, 0.032527256892067175, 0.030204648492509915, 0.027365467573320847, 0.027032214363312827, 0.02420701709050278, 0.023061339617985475, 0.01777797837675025, 0.01563615195493263, 0.012463366113595711, 0.010100584633683499, 0.009180371415467865, 0.006987098012937018, 0.00557468407923756, 0.00557468407923756]
Macroupper=[4028358.5600000005, 3908358.5600000015, 3588358.56, 3428358.56, 3228358.5600000005, 2908358.5600000005, 2948358.560000001, 3268358.5600000015, 2348358.560000001, 2028358.5600000003, 1668358.5600000008, 1628358.5600000005, 1308358.5600000003, 1188358.5600000003, 708358.5600000002, 548358.56, 348358.56000000006, 228358.56000000003, 188358.56000000003, 108358.56000000001, 68358.56000000001, 28358.560000000005]
Macromass=[8.25e-06, 1.3749999999999999e-05, 1.925e-05, 2.475e-05, 3.0250000000000003e-05, 4.125e-05, 4.675e-05, 5.2249999999999996e-05, 8.25e-05, 0.0001375, 0.00019250000000000002, 0.0002475, 0.0003575, 0.00046750000000000003, 0.000825, 0.001375, 0.0019250000000000003, 0.002475, 0.0030250000000000003, 0.003575, 0.004125, 0.005225]

macro = [[0.0]*2 for i in range(len(Macroupper))]
for i in range(0,len(Macroupper)):
    macro[i][0]=Macromass[i]
    macro[i][1]=Macroupper[i]
    
macro1 = [[0.0]*2 for i in range(len(Macroupper))]
for i in range(0,len(Macroupper)):
    macro1[i][0]=Macromass[len(Macroupper)-i-1]
    macro1[i][1]=Macrolower[i]
print(macro)
print(macro1)

# %%
Micamass=[0.04125, 0.052250000000000005, 0.0825, 0.1375, 0.1925, 0.2475, 0.30250000000000005, 0.35750000000000004, 0.4125, 0.4675, 0.5225000000000001, 0.825, 1.375, 1.9250000000000003, 2.475, 3.0250000000000004, 3.575, 4.125, 4.675000000000001, 5.2250000000000005, 8.25, 13.75, 19.25, 24.75, 30.250000000000004, 35.75, 41.25, 46.75, 52.25000000000001] 
Micalower=[5.6145877691691, 5.561689028052812, 5.246964075141917, 5.048101916993175, 4.965222775224983, 4.858642522058866, 4.748456491291296, 4.68046539581416, 4.657469296561756, 4.587434458566436, 4.657469296561756, 4.182977715115939, 4.072021797392772, 3.834820298684402, 3.674097365453487, 3.5720845061205844, 3.5370327358820584, 3.428399634905032, 3.3139456258002773, 3.3527974511352303, 2.7740581547362866, 2.4879153643789547, 2.287678585214125, 2.2152821789457557, 2.065222833013728, 1.9958513449929858, 1.9596352228083802, 1.9596352228083802, 1.9596352228083802]
Micaupper=[4828358.5600000005, 4708358.560000001, 4028358.5600000005, 3908358.5600000015, 3588358.56, 3428358.56, 3228358.5600000005, 2908358.5600000005, 2948358.560000001, 3268358.5600000015, 2348358.560000001, 2028358.5600000003, 1668358.5600000008, 1628358.5600000005, 1308358.5600000003, 1188358.5600000003, 708358.5600000002, 548358.56, 348358.56000000006, 228358.56000000003, 188358.56000000003, 108358.56000000001, 68358.56000000001, 28358.560000000005]

mica = [[0.0]*2 for i in range(len(Micaupper))]
for i in range(0,len(Micaupper)):
    mica[i][0]=Micamass[i]
    mica[i][1]=Micaupper[i]
    
mica1 = [[0.0]*2 for i in range(len(Micaupper))]
for i in range(0,len(Micaupper)):
    mica1[i][0]=Micamass[len(Micaupper)-i-1]
    mica1[i][1]=Micalower[i]
print(mica)
print(mica1)

# %%
#charge constraints for ######## \sigma_x = 10^{-25}cm^2

from scipy.interpolate import interp1d
import io
import csv
import sys
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import scipy
import os

pi=np.pi
rx = np.sqrt((10**-25)/pi)


from pylab import *


macro=[[8.25e-06, 4028358.5600000005], [1.3749999999999999e-05, 3908358.5600000015], [1.925e-05, 3588358.56], 
       [2.475e-05, 3428358.56], [3.0250000000000003e-05, 3228358.5600000005], [4.125e-05, 2908358.5600000005], 
       [4.675e-05, 2948358.560000001], [5.2249999999999996e-05, 3268358.5600000015], [8.25e-05, 2348358.560000001], 
      [0.1375, 2.7740581547362866], [0.0825, 2.4879153643789547], [0.052250000000000005, 2.287678585214125], 
      [0.04125, 2.2152821789457557],[0.04125*10**-16, 2.2152821789457557],[0.04125*10**-16, 4828358.5600000005],
      [0.04125, 4828359.5600000005]]

CMB=[[1.2*10**15,1.84*10**14],[10**-13,1.6],[10**-13,5.3*10**40],[1.2*10**15,5.31*10**40],
    [1.2*10**15,1.84*10**14]]

neutron = [[8*10**9,2.7*10**8],[10*10**9,2.58*10**8],[10**10,10**15],
           [0.0006,2.45*10**8],[10**10,2.58*10**8]]

# mica=[[0.04125*10**-16, 2.2152821789457557],[0.04125*10**-16, 4828358.5600000005],
#       [10**-4,4828358.5600000005],[10**-4, 2.21528217],[0.04225*10**-16, 2.2152821789457557]]

# macro=[[8.25e-16, 0.00557468407923756],
#        [8.25e-16, 4028358.5600000005],[10**-7,4028358.5600000005],[10**-7, 0.00557468407923756],
#        [8.26e-16, 0.00557468407923756]]

M1=np.logspace(-13,23)
M = np.logspace(-13,15.08)
M2 = np.logspace(15.08,23)


def BH(M):
    f = pi*(3*10**5)**2 *(M/(2.*10**33))**2
    return f

def MAG(M):
    f = 6*10**16*M
    return f

def SELF(M):
    f = (M**0.75)*3*10**16
    return f

def nuclei(M):
    f = np.sqrt(3.33*10**37*rx)*M
    return f

#Define Plot
fig = plt.figure()
ax = fig.add_subplot(111)

#X-axis
ax.set_xlabel('$M_\t{X}$ [g]',fontsize=18)
#xmin=-2
#xmax=40
ax.set_xlim([M1.min(),M1.max()])

#Y-axis
ymin=10**-3#nuc(M1).min()#10**(-15)
ymax=float(10**36)#nuc(M1).max()#10**15
ax.set_ylim([ymin,ymax])
ax.set_ylabel('Electric Charge',fontsize=18)

# ax.loglog(M1, BH(M1), 'k', markersize=4, color='m',lw=3,label='Black holes',zorder=5)

ax.loglog(M, nuclei(M), 'r', markersize=4, color='k',lw=3,label='Resized nuclei',zorder=8)


linemacro = plt.Polygon(macro, closed=None, fill=True, facecolor='green', edgecolor='black',alpha=2, hatch="//",lw=1,zorder=5)# edgecolor='r'
plt.gca().add_line(linemacro)

linemica = plt.Polygon(mica, closed=None, fill=True, facecolor='blue', edgecolor='black',alpha=2, hatch="//",lw=1,zorder=4)# edgecolor='r'
plt.gca().add_line(linemica)

lineneutron = plt.Polygon(neutron, closed=None, fill=True, facecolor='red', edgecolor='black',alpha=2, hatch="//",lw=1,zorder=4)# edgecolor='r'
plt.gca().add_line(lineneutron)

lineCMB = plt.Polygon(CMB, closed=None, fill=True, facecolor='grey', edgecolor='black',alpha=0.4, hatch="",lw=1,zorder=6)# edgecolor='r'
plt.gca().add_line(lineCMB)

plt.fill_between(M, MAG(M),ymax,where=None, facecolor='orange',edgecolor='black',hatch="",alpha=1,zorder=4)

plt.fill_between(M, SELF(M),ymax,where=None, facecolor='purple',edgecolor='black',hatch="",alpha=1,zorder=3)

plt.fill_between(M, SELF(M),ymax,where=None, facecolor='purple',edgecolor='black',hatch="",alpha=1,zorder=3)

plt.fill_between(M2, ymin,ymax,where=None, facecolor='white',edgecolor='black',hatch="+",alpha=1,zorder=9)

# leg = ax.legend(loc='upper left')
ax.grid(True)
plt.tight_layout()
plt.savefig('chargeverysmallsigma.pdf')

plt.show()

# %%
#charge constraints for ######## \sigma_x = 10^{-20}cm^2

from scipy.interpolate import interp1d
import io
import csv
import sys
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import scipy
import os

from pylab import *
pi=np.pi
rx = np.sqrt((10**-20)/pi)

macro=[[8.25e-06, 4028358.5600000005], [1.3749999999999999e-05, 3908358.5600000015], [1.925e-05, 3588358.56], 
       [2.475e-05, 3428358.56], [3.0250000000000003e-05, 3228358.5600000005], [4.125e-05, 2908358.5600000005], 
       [4.675e-05, 2948358.560000001], [5.2249999999999996e-05, 3268358.5600000015], [8.25e-05, 2348358.560000001], 
       [0.0001375, 2028358.5600000003], [0.00019250000000000002, 1668358.5600000008], [0.0002475, 1628358.5600000005], 
       [0.0003575, 1308358.5600000003], [0.00046750000000000003, 1188358.5600000003], [0.000825, 708358.5600000002], 
       [0.001375, 548358.56], [0.0019250000000000003, 348358.56000000006], [0.002475, 228358.56000000003], 
       [0.0030250000000000003, 188358.56000000003], [0.003575, 108358.56000000001], [0.004125, 68358.56000000001], 
       [0.005225, 28358.560000000005],[0.005225, 0.04275455794733869], [0.004125, 0.04210369883848801], 
       [0.003575, 0.04031872769101489], [0.0030250000000000003, 0.03939708544950129], [0.002475, 0.03821496688786844], 
       [0.0019250000000000003, 0.036246507466864857], [0.001375, 0.036498159779284514], [0.000825, 0.03845419097636563], 
       [0.00046750000000000003, 0.032527256892067175], [0.0003575, 0.030204648492509915], [0.0002475, 0.027365467573320847], 
       [0.00019250000000000002, 0.027032214363312827], [0.0001375, 0.02420701709050278], [8.25e-05, 0.023061339617985475], 
       [5.2249999999999996e-05, 0.01777797837675025], [4.675e-05, 0.01563615195493263], [4.125e-05, 0.012463366113595711], 
       [3.0250000000000003e-05, 0.010100584633683499], [2.475e-05, 0.009180371415467865], [1.925e-05, 0.006987098012937018], 
       [1.3749999999999999e-05, 0.00557468407923756], [8.25e-06, 0.00557468407923756],[8.25e-16, 0.00557468407923756],
       [8.25e-16, 4028358.5600000005],[8.25e-06, 4028359.5600000005]]

mica=[[0.04125, 4828358.5600000005], [0.052250000000000005, 4708358.560000001], [0.0825, 4028358.5600000005], 
      [0.1375, 3908358.5600000015], [0.1925, 3588358.56], [0.2475, 3428358.56], [0.30250000000000005, 3228358.5600000005], 
      [0.35750000000000004, 2908358.5600000005], [0.4125, 2948358.560000001], [0.4675, 3268358.5600000015], 
      [0.5225000000000001, 2348358.560000001], [0.825, 2028358.5600000003], [1.375, 1668358.5600000008], 
      [1.9250000000000003, 1628358.5600000005], [2.475, 1308358.5600000003], [3.0250000000000004, 1188358.5600000003], 
      [3.575, 708358.5600000002], [4.125, 548358.56], [4.675000000000001, 348358.56000000006], 
      [5.2250000000000005, 228358.56000000003], [8.25, 188358.56000000003], [13.75, 108358.56000000001], 
      [19.25, 68358.56000000001], [24.75, 28358.560000000005],[55,28358.56],[55,5.614], 
      [24.75, 5.6145877691691], [19.25, 5.561689028052812], 
      [13.75, 5.246964075141917], [8.25, 5.048101916993175], [5.2250000000000005, 4.965222775224983], 
      [4.675000000000001, 4.858642522058866], [4.125, 4.748456491291296], [3.575, 4.68046539581416], 
      [3.0250000000000004, 4.657469296561756], [2.475, 4.587434458566436], [1.9250000000000003, 4.657469296561756], 
      [1.375, 4.182977715115939], [0.825, 4.072021797392772], [0.5225000000000001, 3.834820298684402], 
      [0.4675, 3.674097365453487], [0.4125, 3.5720845061205844], [0.35750000000000004, 3.5370327358820584], 
      [0.30250000000000005, 3.428399634905032], [0.2475, 3.3139456258002773], [0.1925, 3.3527974511352303], 
      [0.1375, 2.7740581547362866], [0.0825, 2.4879153643789547], [0.052250000000000005, 2.287678585214125], 
      [0.04125, 2.2152821789457557],[0.04125*10**-16, 2.2152821789457557],[0.04125*10**-16, 4828358.5600000005],
      [0.04125, 4828359.5600000005]]

CMB=[[10**20,5.3*10**16],[10**-13,1.6],[10**-13,5.3*10**40],[10**20,5.31*10**40],
    [10**20,5.31*10**16]]

neutron = [[8*10**9,2.7*10**8],[10*10**9,2.58*10**8],[10**10,10**15],
           [0.0006,2.45*10**8],[10**10,2.58*10**8]]

# mica=[[0.04125*10**-16, 2.2152821789457557],[0.04125*10**-16, 4828358.5600000005],
#       [10**-4,4828358.5600000005],[10**-4, 2.21528217],[0.04225*10**-16, 2.2152821789457557]]

# macro=[[8.25e-16, 0.00557468407923756],
#        [8.25e-16, 4028358.5600000005],[10**-7,4028358.5600000005],[10**-7, 0.00557468407923756],
#        [8.26e-16, 0.00557468407923756]]

M1=np.logspace(-13,23)
M = np.logspace(-13,17.58)
M2 = np.logspace(17.58,23)
MMacro = np.logspace(-13,-2.2819)

def BH(M):
    f = pi*(3*10**5)**2 *(M/(2.*10**33))**2
    return f

def MAG(M):
    f = 6*10**16*M
    return f

def SELF(M):
    f = (M**0.75)*3*10**16
    return f

def nuclei(M):
    f = np.sqrt(3.33*10**37*rx)*M
    return f

#Define Plot
fig = plt.figure()
ax = fig.add_subplot(111)

#X-axis
ax.set_xlabel('$M_\t{X}$ [g]',fontsize=18)
#xmin=-2
#xmax=40
ax.set_xlim([M1.min(),M1.max()])

#Y-axis
ymin=10**-3#nuc(M1).min()#10**(-15)
ymax=float(10**36)#nuc(M1).max()#10**15
ax.set_ylim([ymin,ymax])
ax.set_ylabel('Electric Charge',fontsize=18)

ax.loglog(M1, BH(M1), 'k', markersize=4, color='m',lw=3,label='Black holes',zorder=5)

ax.loglog(M, nuclei(M), 'b', markersize=4, color='k',lw=3,label='Resized nuclei',zorder=8)

linemacro = plt.Polygon(macro, closed=None, fill=True, facecolor='green', edgecolor='black',alpha=1, hatch="//",lw=1,zorder=5)# edgecolor='r'
plt.gca().add_line(linemacro)

linemica = plt.Polygon(mica, closed=None, fill=True, facecolor='blue', edgecolor='black',alpha=1, hatch="//",lw=1,zorder=4)# edgecolor='r'
plt.gca().add_line(linemica)

lineneutron = plt.Polygon(neutron, closed=None, fill=True, facecolor='red', edgecolor='black',alpha=2, hatch="//",lw=1,zorder=4)# edgecolor='r'
plt.gca().add_line
      [24.75, 5.6145877691691], [19.25, 5.561689028052812], 
      [13.75, 5.246964075141917], [8.25, 5.048101916993175], [5.2250000000000005, 4.965222775224983], 
      [4.675000000000001, 4.858642522058866], [4.125, 4.748456491291296], [3.575, 4.68046539581416], 
      [3.0250000000000004, 4.657469296561756], [2.475, 4.587434458566436], [1.9250000000000003, 4.657469296561756], 
      [1.375, 4.182977715115939], [0.825, 4.072021797392772], [0.5225000000000001, 3.834820298684402], 
      [0.4675, 3.674097365453487], [0.4125, 3.5720845061205844], [0.35750000000000004, 3.5370327358820584], 
      [0.30250000000000005, 3.428399634905032], [0.2475, 3.3139456258002773], [0.1925, 3.3527974511352303], 
      [0.1375, 2.7740581547362866], [0.0825, 2.4879153643789547], [0.052250000000000005, 2.287678585214125], 
      [0.04125, 2.2152821789457557],[2.7*10**-10, 2.2152821789457557],[2.7*10**-10, 4828358.5600000005],
      [0.04125, 4828359.5600000005]]

neutron = [[8*10**9,2.7*10**8],[10*10**9,2.58*10**8],[10**10,10**15],
           [0.01,10**9],[0.01,2.46*10**8],[10**10,2.58*10**8]]

CMB=[[10**20,5.3*10**16],[2.2*10**-9,249],[2.2*10**-9,10**-4],[10**-13,10**-4],[10**-13,5.3*10**40],[10**20,5.31*10**40],
    [10**20,5.31*10**16]]

M1=np.logspace(-13,23)
M = np.logspace(-13,20.08)
M2 = np.logspace(20.08,23)
MMacro = np.logspace(-9.569,-2.2819)
MMica =  np.logspace(-9.569,1.74)


def BH(M):
    f = pi*(3*10**5)**2 *(M/(2.*10**33))**2
    return f

def MAG(M):
    f = 6*10**16*M
    return f

def SELF(M):
    f = (M**0.75)*3*10**16
    return f

def nuclei(M):
    f = np.sqrt(3.33*10**37*rx)*M
    return f

#Define Plot
fig = plt.figure()
ax = fig.add_subplot(111)

#X-axis
ax.set_xlabel('$M_\t{X}$ [g]',fontsize=18)
#xmin=-2
#xmax=40
ax.set_xlim([M1.min(),M1.max()])

#Y-axis
ymin=10**-3#nuc(M1).min()#10**(-15)
ymax=float(10**36)#nuc(M1).max()#10**15
ax.set_ylim([ymin,ymax])
ax.set_ylabel('Electric Charge',fontsize=18)

ax.loglog(M1, BH(M1), 'k', markersize=4, color='m',lw=3,label='Black holes',zorder=5)

ax.loglog(M, nuclei(M), 'b', markersize=4, color='k',lw=3,label='Resized nuclei',zorder=8)

linemacro = plt.Polygon(macro, closed=None, fill=True, facecolor='green', edgecolor='black',alpha=1, hatch="//",lw=1,zorder=5)# edgecolor='r'
plt.gca().add_line(linemacro)

linemica = plt.Polygon(mica, closed=None, fill=True, facecolor='blue', edgecolor='black',alpha=1, hatch="//",lw=0.8,zorder=4)# edgecolor='r'
plt.gca().add_line(linemica)

lineneutron = plt.Polygon(neutron, closed=None, fill=True, facecolor='red', edgecolor='black',alpha=2, hatch="//",lw=1,zorder=4)# edgecolor='r'
plt.gca().add_line(lineneutron)

lineCMB = plt.Polygon(CMB, closed=None, fill=True, facecolor='grey', edgecolor='black',alpha=0.4, hatch="",lw=1,zorder=5)# edgecolor='r'
plt.gca().add_line(lineCMB)

plt.fill_between(M, SELF(M),ymax,where=None, facecolor='purple',edgecolor='black',hatch="",alpha=1,zorder=3,lw=1)

plt.fill_between(M, MAG(M),ymax,where=None, facecolor='orange',edgecolor='black',hatch="",alpha=1,zorder=4,lw=1)

plt.fill_between(MMacro, 10**-5,1000,where=None, facecolor='green',edgecolor='black',hatch="",alpha=1,zorder=3,lw=0.8)

plt.fill_between(MMica, 10**-5,1000,where=None, facecolor='blue',edgecolor='black',hatch="",alpha=1,zorder=2,lw=0.8)

plt.fill_between(M2, ymin,ymax,where=None, facecolor='white',edgecolor='black',hatch="+",alpha=1,zorder=9)


legneutron = Rectangle((0, 0), 1, 1, fc="red",edgecolor='black', hatch="//",alpha=1)
legmacro = Rectangle((0, 0), 1, 1, fc="green",edgecolor='black', hatch="//",alpha=1)
legmica = Rectangle((0, 0), 1, 1, fc="blue",edgecolor='black', alpha=1,hatch="//")
legself = Rectangle((0, 0), 1, 1, fc="purple",edgecolor='black', hatch="",alpha=1)
legcmb = Rectangle((0, 0), 1, 1, fc="grey",edgecolor='black', hatch="",alpha=0.4)
legmag = Rectangle((0, 0), 1, 1, fc="orange",edgecolor='black', alpha=1,hatch="")

ax.grid(True)
plt.tight_layout()
plt.savefig('chargemoderatesigma.pdf')

plt.show()

# %%
#charge constraints for ######## \sigma_x = 10^{-10}cm^2

import csv
import sys
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import scipy
import os

from pylab import *

pi=np.pi
rx = np.sqrt((10**-10)/pi)

macro=[[2.7e-05, 4028358.6600000005], [3.0250000000000003e-05, 3228358.5600000005], [4.125e-05, 2908358.5600000005], 
       [4.675e-05, 2948358.560000001], [5.2249999999999996e-05, 3268358.5600000015], [8.25e-05, 2348358.560000001], 
       [0.0001375, 2028358.5600000003], [0.00019250000000000002, 1668358.5600000008], [0.0002475, 1628358.5600000005], 
       [0.0003575, 1308358.5600000003], [0.00046750000000000003, 1188358.5600000003], [0.000825, 708358.5600000002], 
       [0.001375, 548358.56], [0.0019250000000000003, 348358.56000000006], [0.002475, 228358.56000000003], 
       [0.0030250000000000003, 188358.56000000003], [0.003575, 108358.56000000001], [0.004125, 68358.56000000001], 
def BH(M):
    f = pi*(3*10**5)**2 *(M/(2.*10**33))**2
    return f

def MAG(M):
    f = 6*10**16*M
    return f

def SELF(M):
    f = (M**0.75)*3*10**16
    return f

def nuclei(M):
    f = np.sqrt(3.33*10**37*rx)*M
    return f

#Define Plot
fig = plt.figure()
ax = fig.add_subplot(111)

#X-axis
ax.set_xlabel('$M_\t{X}$ [g]',fontsize=18)
#xmin=-2
#xmax=40
ax.set_xlim([M1.min(),M1.max()])

#Y-axis
ymin=10**-3#nuc(M1).min()#10**(-15)
ymax=float(10**36)#nuc(M1).max()#10**15
ax.set_ylim([ymin,ymax])
ax.set_ylabel('Electric Charge',fontsize=18)

ax.loglog(M1, BH(M1), 'k', markersize=4, color='m',lw=3,label='Black holes',zorder=5)

ax.loglog(M, nuclei(M), 'b', markersize=4, color='k',lw=3,label='Resized nuclei',zorder=8)

linemacro = plt.Polygon(macro, closed=None, fill=True, facecolor='green', edgecolor='black',alpha=2, hatch="//",lw=1,zorder=5)# edgecolor='r'
plt.gca().add_line(linemacro)

linemica = plt.Polygon(mica, closed=None, fill=True, facecolor='blue', edgecolor='black',alpha=2, hatch="//",lw=1,zorder=4)# edgecolor='r'
plt.gca().add_line(linemica)

lineneutron = plt.Polygon(neutron, closed=None, fill=True, facecolor='red', edgecolor='black',alpha=2, hatch="//",lw=1,zorder=4)# edgecolor='r'
plt.gca().add_line(lineneutron)

lineCMB = plt.Polygon(CMB, closed=None, fill=True, facecolor='grey', edgecolor='black',alpha=0.4, hatch="",lw=1,zorder=6)# edgecolor='r'
plt.gca().add_line(lineCMB)

plt.fill_between(M, MAG(M),ymax,where=None, facecolor='orange',edgecolor='black',hatch="",alpha=1,zorder=4)

plt.fill_between(M, SELF(M),ymax,where=None, facecolor='purple',edgecolor='black',hatch="",alpha=1,zorder=3)

plt.fill_between(MMacro, 10**-5,1000,where=None, facecolor='green',edgecolor='black',hatch="",alpha=1,zorder=3,lw=0.8)

plt.fill_between(MMica, 10**-5,1000,where=None, facecolor='blue',edgecolor='black',hatch="",alpha=1,zorder=2,lw=0.8)

plt.fill_between(M2, ymin,ymax,where=None, facecolor='white',edgecolor='black',hatch="+",alpha=1,zorder=9)

legneutron = Rectangle((0, 0), 1, 1, fc="red",edgecolor='black', hatch="//",alpha=1)
legmacro = Rectangle((0, 0), 1, 1, fc="green",edgecolor='black', hatch="//",alpha=1)
legmica = Rectangle((0, 0), 1, 1, fc="blue",edgecolor='black', alpha=1,hatch="//")
legself = Rectangle((0, 0), 1, 1, fc="purple",edgecolor='black', hatch="",alpha=1)
legcmb = Rectangle((0, 0), 1, 1, fc="grey",edgecolor='black', hatch="",alpha=0.4)
legmag = Rectangle((0, 0), 1, 1, fc="orange",edgecolor='black', alpha=1,hatch="")

ax.grid(True)
plt.tight_layout()
plt.savefig('chargelargesigma.pdf')

plt.show()

# %%
#charge constraints for ######## \sigma_x = 10^{-5}cm^2

import csv
import sys
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import scipy
import os

from pylab import *

pi=np.pi
rx = np.sqrt((10**-5)/pi)


mica=[[2.7, 1628358.5600000005], [3.0250000000000004, 1188358.5600000003], 
      [3.575, 708358.5600000002], [4.125, 548358.56], [4.675000000000001, 348358.56000000006], 
      [5.2250000000000005, 228358.56000000003], [8.25, 188358.56000000003], [13.75, 108358.56000000001], 
      [19.25, 68358.56000000001], [24.75, 28358.560000000005],[55,28358], [55, 5.6145877691691], [19.25, 5.561689028052812], 
      [13.75, 5.246964075141917], [8.25, 5.048101916993175], [5.2250000000000005, 4.965222775224983], 
      [4.675000000000001, 4.858642522058866], [4.125, 4.748456491291296], [3.575, 4.68046539581416], 
      [3.0250000000000004, 4.657469296561756],
      [2.7, 4.182977715115939],[2.7, 2.2152821789457557],[2.7, 4828358.5600000005],
      [2.7, 4828359.5600000005]]

neutron = [[8*10**9,2.7*10**8],[10*10**9,2.58*10**8],[10**10,10**15],
           [10**8,10**14],[10**8,2.46*10**8],[10**10,2.58*10**8]]

CMB=[[10**23,5.581*10**18],[2.2*10**-4,78611],[2.2*10**-4,10**-4],[10**-13,10**-4],[10**-13,5.3*10**40],[10**23,5.31*10**40],
    [10**23,1.58*10**18]]

M1=np.logspace(-13,23)
M = np.logspace(-13,23)
Melasticself = np.logspace(-13,-5)
MMica =  np.logspace(0.4313,1.74)
MNS = np.logspace(8,10)

def BH(M):
    f = pi*(3*10**5)**2 *(M/(2.*10**33))**2
    return f

def MAG(M):
    f = 6*10**16*M
    return f

def MES(M):
    f = 10**-4
    return f

def SELF(M):
    f = (M**0.75)*3*10**16
    return f

def nuclei(M):
    f = np.sqrt(3.33*10**37*rx)*M
    return f

#Define Plot
fig = plt.figure()
ax = fig.add_subplot(111)

#X-axis
ax.set_xlabel('$M_\t{X}$ [g]',fontsize=18)
#xmin=-2
#xmax=40
ax.set_xlim([M1.min(),M1.max()])

#Y-axis
ymin=10**-3#nuc(M1).min()#10**(-15)
ymax=float(10**36)#nuc(M1).max()#10**15
ax.set_ylim([ymin,ymax])
ax.set_ylabel('Electric Charge',fontsize=18)

ax.loglog(M1, BH(M1), 'k', markersize=4, color='m',lw=3,label='Black holes',zorder=5)

ax.loglog(M, nuclei(M), 'b', markersize=4, color='k',lw=3,label='Resized nuclei',zorder=8)

linemica = plt.Polygon(mica, closed=None, fill=True, facecolor='blue', edgecolor='black',alpha=2, hatch="//",lw=1,zorder=4)# edgecolor='r'
plt.gca().add_line(linemica)

lineneutron = plt.Polygon(neutron, closed=None, fill=True, facecolor='red', edgecolor='black',alpha=2, hatch="//",lw=1,zorder=4)# edgecolor='r'
plt.gca().add_line(lineneutron)


lineCMB = plt.Polygon(CMB, closed=None, fill=True, facecolor='grey', edgecolor='black',alpha=0.4, hatch="",lw=1,zorder=5)# edgecolor='r'
plt.gca().add_line(lineCMB)

plt.fill_between(M, SELF(M),ymax,where=None, facecolor='purple',edgecolor='black',hatch="",alpha=1,zorder=3)

plt.fill_between(M, MAG(M),ymax,where=None, facecolor='orange',edgecolor='black',hatch="",alpha=1,zorder=4)

plt.fill_between(MMica, 10**-5,1000,where=None, facecolor='blue',edgecolor='black',hatch="",alpha=1,zorder=2,lw=0.8)

plt.fill_between(MNS, 10**-5,10**9,where=None, facecolor='red',edgecolor='black',hatch="",alpha=1,zorder=2,lw=0.8)

plt.fill_between(Melasticself, MES(Melasticself), MAG(Melasticself),where=None, facecolor='purple',edgecolor='black',hatch="",alpha=1,zorder=4)

legneutron = Rectangle((0, 0), 1, 1, fc="red",edgecolor='black', hatch="//",alpha=1)
legmacro = Rectangle((0, 0), 1, 1, fc="green",edgecolor='black', hatch="//",alpha=1)
legmica = Rectangle((0, 0), 1, 1, fc="blue",edgecolor='black', alpha=1,hatch="//")
legself = Rectangle((0, 0), 1, 1, fc="purple",edgecolor='black', hatch="",alpha=1)
legcmb = Rectangle((0, 0), 1, 1, fc="grey",edgecolor='black', hatch="",alpha=0.4)
legmag = Rectangle((0, 0), 1, 1, fc="orange",edgecolor='black', alpha=1,hatch="")

ax.grid(True)
plt.tight_layout()
plt.savefig('chargeverylargesigma.pdf')

plt.show()

# %%
#charge constraints for ######## \sigma_x = 10^{0}cm^2 = 1 cm^2

import csv
import sys
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import scipy
import os

from pylab import *

pi=np.pi
rx = np.sqrt((10**0)/pi)


CMB=[[10**23,5.581*10**18],[2.2*10**-4,78611],[2.2*10**-4,10**-4],[10**-13,10**-4],[10**-13,5.3*10**40],[10**23,5.31*10**40],
    [10**23,1.58*10**18]]

M1=np.logspace(-13,23)
M = np.logspace(-13,23)
Melasticself = np.logspace(-13,0)

def BH(M):
    f = pi*(3*10**5)**2 *(M/(2.*10**33))**2
    return f

def MAG(M):
    f = 6*10**16*M
    return f

def MES(M):
    f = 10**-4
    return f

def SELF(M):
    f = (M**0.75)*3*10**16
    return f

def nuclei(M):
    f = np.sqrt(3.33*10**37*rx)*M
    return f

#Define Plot
fig = plt.figure()
ax = fig.add_subplot(111)

#X-axis
ax.set_xlabel('$M_\t{X}$ [g]',fontsize=18)
#xmin=-2
#xmax=40
ax.set_xlim([M1.min(),M1.max()])

#Y-axis
ymin=10**-3#nuc(M1).min()#10**(-15)
ymax=float(10**36)#nuc(M1).max()#10**15
ax.set_ylim([ymin,ymax])
ax.set_ylabel('Electric Charge',fontsize=18)

ax.loglog(M1, BH(M1), 'k', markersize=4, color='m',lw=3,label='Black holes',zorder=5)

ax.loglog(M, nuclei(M), 'b', markersize=4, color='k',lw=3,label='Resized nuclei',zorder=8)

lineCMB = plt.Polygon(CMB, closed=None, fill=True, facecolor='grey', edgecolor='black',alpha=0.4, hatch="",lw=1,zorder=5)# edgecolor='r'
plt.gca().add_line(lineCMB)

plt.fill_between(M, SELF(M),ymax,where=None, facecolor='purple',edgecolor='black',hatch="",alpha=1,zorder=3)

plt.fill_between(M, MAG(M),ymax,where=None, facecolor='orange',edgecolor='black',hatch="",alpha=1,zorder=5)

plt.fill_between(Melasticself, MES(Melasticself), MAG(Melasticself),where=None, facecolor='purple',edgecolor='',hatch="",alpha=1,zorder=4)

legneutron = Rectangle((0, 0), 1, 1, fc="red",edgecolor='black', hatch="//",alpha=1)
legmacro = Rectangle((0, 0), 1, 1, fc="green",edgecolor='black', hatch="//",alpha=1)
legmica = Rectangle((0, 0), 1, 1, fc="blue",edgecolor='black', alpha=1,hatch="//")
legself = Rectangle((0, 0), 1, 1, fc="purple",edgecolor='black', hatch="",alpha=1)
legcmb = Rectangle((0, 0), 1, 1, fc="grey",edgecolor='black', hatch="",alpha=0.4)
legmag = Rectangle((0, 0), 1, 1, fc="orange",edgecolor='black', alpha=1,hatch="")

plt.plot((0.9, 0.9), (10**-5, 2.5*10**16), 'black', lw=1.2,zorder=6,alpha=0.6)

#leg = ax.legend(loc='upper left', shadow=True)
#leg2 = legend(([legneutron, legmica,legmacro,legself,legcmb,legmag]),[ "Superbursts", "Ancient mica", "MACRO", "Self-Interactions", "CMB", "Magnetic Field"],loc='lower right')
# gca().add_artist(leg) #Needto add this back otherwise leg2 removes it  ,legBBNcausalT,legBBNcausalM   ,"Causality (T)","Causality (M)"



# textstr2='CMB'
# props = dict(boxstyle='round', facecolor='none', alpha=0.)

# # place a text box in upper left in axes coords
# ax.text(0.2, 0.8, textstr2, transform=ax.transAxes, fontsize=10,
#     verticalalignment='top', bbox=props)

# textstr3='Mica'
# props = dict(boxstyle='round', facecolor='none', alpha=0.)

# # place a text box in upper left in axes coords
# ax.text(0.002, 0.15, textstr3, transform=ax.transAxes, fontsize=10,
#     verticalalignment='top', bbox=props)

ax.grid(True)
plt.tight_layout()
plt.savefig('chargeLSSsigma.pdf')

plt.show()

# %%
#charge constraints for ######## \sigma_x = 10^{5}cm^2

import csv
import sys
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import scipy
import os

from pylab import *

pi=np.pi
rx = np.sqrt((10**5)/pi)

CMB=[[10**20,5.3*10**16],[2.2*10**11,78611],[2.2*10**11,10**-4],[10**-13,10**-4],[10**-13,5.3*10**40],[10**20,5.31*10**40],
    [10**20,5.31*10**16]]

M1=np.logspace(-13,20)
M = np.logspace(-13,20)
Melasticself = np.logspace(-13,5)

def BH(M):
    f = pi*(3*10**5)**2 *(M/(2.*10**33))**2
    return f

def MAG(M):
    f = 6*10**16*M
    return f

def MES(M):
    f = 10**-4
    return f

def SELF(M):
    f = (M**0.75)*3*10**16
    return f

def nuclei(M):
    f = np.sqrt(3.33*10**37*rx)*M
    return f

#Define Plot
fig = plt.figure()
ax = fig.add_subplot(111)

#X-axis
ax.set_xlabel('$M_\t{X}$ [g]',fontsize=18)
#xmin=-2
#xmax=40
ax.set_xlim([M1.min(),M1.max()])

#Y-axis
ymin=10**-3#nuc(M1).min()#10**(-15)
ymax=float(10**36)#nuc(M1).max()#10**15
ax.set_ylim([ymin,ymax])
ax.set_ylabel('Electric Charge',fontsize=18)

ax.loglog(M1, BH(M1), 'k', markersize=4, color='m',lw=3,label='Black holes',zorder=5)

ax.loglog(M, nuclei(M), 'b', markersize=4, color='k',lw=3,label='Resized nuclei',zorder=8)

lineCMB = plt.Polygon(CMB, closed=None, fill=True, facecolor='grey', edgecolor='black',alpha=0.4, hatch="",lw=1,zorder=5)# edgecolor='r'
plt.gca().add_line(lineCMB)

plt.fill_between(M, MAG(M),ymax,where=None, facecolor='orange',edgecolor='black',hatch="",alpha=1,zorder=5)

plt.fill_between(M, SELF(M),ymax,where=None, facecolor='purple',edgecolor='black',hatch="",alpha=1,zorder=3)

plt.fill_between(Melasticself, MES(Melasticself), MAG(Melasticself),where=None, facecolor='purple',edgecolor='',hatch="",alpha=1.0,zorder=4)

legneutron = Rectangle((0, 0), 1, 1, fc="red",edgecolor='black', hatch="//",alpha=1)
legmacro = Rectangle((0, 0), 1, 1, fc="green",edgecolor='black', hatch="//",alpha=1)
legmica = Rectangle((0, 0), 1, 1, fc="blue",edgecolor='black', alpha=1,hatch="//")
legself = Rectangle((0, 0), 1, 1, fc="purple",edgecolor='black', hatch="",alpha=1)
legcmb = Rectangle((0, 0), 1, 1, fc="grey",edgecolor='black', hatch="",alpha=0.4)
legmag = Rectangle((0, 0), 1, 1, fc="orange",edgecolor='black', alpha=1,hatch="")

plt.plot((9*10**4, 9*10**4), (10**-5, 1.5*10**20), 'black', lw=1.2,zorder=6,alpha=0.6)

ax.grid(True)
plt.tight_layout()
plt.savefig('chargeLargeLSSsigma.pdf')

plt.show()

# %%
#binding energy check for curiosity sake

Z = (10**-7*10**10*1.6*10**-12/(10**-27*4.8*10**-10*4.8*10**-10))**0.5
print(Z)

# %%
import math
uppermacro=4028358.5600000005
M=[]
Zmax=[]
vrel=25000000**2
M2 = 10.0*1.67*10**-27*1000.0
Z2 = 10.0
#Z1 = 10**10 #temp
N = 10.0**23


def fun2(Z1,Mx):
    return 3*10**5*0.5*(math.log(1+1.1383*4.68*10**-9*M2*(vrel)**2/(2*Z1**1.23*Z2*(4.8*10**-10)**2))/(4.68*10**-9*M2*(vrel)**2/(2*Z1**1.23*Z2*(4.8*10**-10)**2) + 0.01321*(4.68*10**-9*M2*(vrel)**2/(2*Z1**1.23*Z2*(4.8*10**-10)**2))**0.21226+0.19593*(4.68*10**-9*M2*(vrel)**2/(2*Z1**1.23*Z2*(4.8*10**-10)**2))**0.5 )) * (N*8.462*10**-15*Z1**0.77*Z2) - 3*10**13*Mx
    #return

f=3*10**5*0.5*(math.log(1+1.1383*4.68*10**-9*M2*(vrel)**2/(2*uppermacro**1.23*Z2*(4.8*10**-10)**2))/(4.68*10**-9*M2*(vrel)**2/(2*uppermacro**1.23*Z2*(4.8*10**-10)**2) + 0.01321*(4.68*10**-9*M2*(vrel)**2/(2*uppermacro**1.23*Z2*(4.8*10**-10)**2))**0.21226+0.19593*(4.68*10**-9*M2*(vrel)**2/(2*uppermacro**1.23*Z2*(4.8*10**-10)**2))**0.5 )) * (1.6*10**-12*N*8.462*10**-15*uppermacro**0.77*Z2)
for i in range(0,26):
    M.append(0.055*10**(-i))
# print(f)

for i in range(0,26):
    if(f/(0.1*0.5*M[i]*(25000000**2))>1.0):
#         print(M[i])
        uppermacro=uppermacro/1
        g=3*10**5*0.5*(math.log(1+1.1383*4.68*10**-9*M2*(vrel)**2/(2*uppermacro**1.23*Z2*(4.8*10**-10)**2))/(4.68*10**-9*M2*(vrel)**2/(2*uppermacro**1.23*Z2*(4.8*10**-10)**2) + 0.01321*(4.68*10**-9*M2*(vrel)**2/(2*uppermacro**1.23*Z2*(4.8*10**-10)**2))**0.21226+0.19593*(4.68*10**-9*M2*(vrel)**2/(2*uppermacro**1.23*Z2*(4.8*10**-10)**2))**0.5 )) * (1.6*10**-12*N*8.462*10**-15*uppermacro**0.77*Z2)
        print(g/(0.1*0.5*M[i]*(25000000**2)),M[i])
#         z0 = fsolve(fun2,2,M[i])
#         print(z0)
# Out:
# 5.166545006209439 5.5e-13
# 51.66545006209439 5.5e-14
# 516.6545006209438 5.5e-15
# 5166.545006209439 5.5e-16
# 51665.45006209439 5.5000000000000006e-17
# 516654.50062094384 5.5e-18
# 5166545.006209439 5.500000000000001e-19
# 51665450.062094375 5.500000000000001e-20
# 516654500.62094396 5.5e-21
# 5166545006.209439 5.5e-22
# 51665450062.0944 5.499999999999999e-23
# 516654500620.9438 5.5000000000000006e-24
# 5166545006209.438 5.5e-25
# 51665450062094.4 5.499999999999999e-26
# 516654500620943.9 5.5e-27

# %%
#final check for charge
ratio = ((10**17)**2*(4.8*10**-10)**2/(10**-9))/(10**10*10**-5/(1.67*10**-23))
print(ratio)

# %%
5.3*10**6*(10**10)**0.5/(10**11)

# %%
M2 = 10.0*1.67*10**-27*1000.0
Z2 = 10.0
#Z1 = 10**10 #temp
N = 10.0**23
vrel=25000000

for i in range(0,20):
    Z1= 10**4*(10**i)
    r=0.5*(math.log(1+1.1383*4.68*10**-9*M2*(vrel)**2/(2*Z1**1.23*Z2*(4.8*10**-10)**2))/(4.68*10**-9*M2*(vrel)**2/(2*Z1**1.23*Z2*(4.8*10**-10)**2) + 0.01321*(4.68*10**-9*M2*(vrel)**2/(2*Z1**1.23*Z2*(4.8*10**-10)**2))**0.21226+0.19593*(4.68*10**-9*M2*(vrel)**2/(2*Z1**1.23*Z2*(4.8*10**-10)**2))**0.5 )) * (N*8.462*10**-15*Z1**0.77*Z2)-5*10**9
    print(r,Z1,10000/(Z1**1.23))
# Out:
# 166276958541.92725 10000 0.12022644346174131
# 152602874681.90433 100000 0.00707945784384138
# 117826591283.54306 1000000 0.0004168693834703355
# 81423550750.24301 10000000 2.454708915685031e-05
# 52515263141.7961 100000000 1.445439770745928e-06
# 32238575444.927902 1000000000 8.511380382023767e-08
# 18802875253.95224 10000000000 5.011872336272725e-09
# 10128782355.120975 100000000000 2.951209226666387e-10
# 4543563473.328384 1000000000000 1.7378008287493765e-11
# 1549591694.25519 10000000000000 1.0232929922807547e-12
# -5000000000.0 100000000000000 6.02559586074358e-14
# -5000000000.0 1000000000000000 3.548133892335757e-15
# -5000000000.0 10000000000000000 2.0892961308540406e-16
# -5000000000.0 100000000000000000 1.2302687708123824e-17
# -5000000000.0 1000000000000000000 7.244359600749906e-19
# -5000000000.0 10000000000000000000 4.26579518801593e-20
# -5000000000.0 100000000000000000000 2.5118864315095823e-21
# -5000000000.0 1000000000000000000000 1.4791083881682086e-22
# ...
